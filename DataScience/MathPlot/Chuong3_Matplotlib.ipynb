# %% [markdown]
# Sử dụng cơ bản bắt đầu với Matplotlib.pyplot, thư viện gồm các hàm tương tự với MATLAB

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.1.1'

# %%
fig, ax = plt.subplots() # Create a figure containing a single axes
ax.plot([1, 2, 3, 4], [1, 4, 2, 3]) # Plot some data on the axes

# %%
fig = plt.figure() # an empty figure with no Axes

# %%
fig, ax = plt.subplots() # a figure with a single Axes
ax.set_title('Can nang vs. Chieu cao')
ax.set_xlabel('Chieu cao (cm)')
ax.set_xlim(100,200)
ax.set_ylabel('Can nang (kg)')
ax.set_ylim(30,100)
heights = np.random.normal(155, 15, 100)
weights = np.random.normal(55, 10, 100)
ax.scatter(heights, weights, marker='x')

# %%
fig, axs = plt.subplots(2, 2) # a figure with a 2x2 grid of Axes
(ax1,ax2),(ax3,ax4) = axs # tuple unpacking
ax1.set_title('Figure 1')
ax2.set_title('Figure 2')
ax3.set_title('Figure 3')
ax4.set_title('Figure 4')
# Out:
# Text(0.5, 1.0, 'Figure 4')

# %%
fig, axs = plt.subplots(2, 2) # a figure with a 2x2 grid of Axes
axs[0,0].set_title('Figure 0.0')
axs[0,1].set_title('Figure 0.1')
axs[1,0].set_title('Figure 1.0')
axs[1,1].set_title('Figure 1.1')
# Out:
# Text(0.5, 1.0, 'Figure 1.1')

# %% [markdown]
# Kiểu dữ liệu đầu vào cho các hàm vẽ biểu đồ
#
# - Các hàm vẽ biểu đồ đều nhận đầu vào là numpy.array, hoặc numpy.ma.masked_array,  hoặc các đối tượng có thể được truyền vào numpy.asarray.
#
# - Các lớp ‘array-like' như đối tượng pandas và numpy.matrix có thể hoạt động không như dự kiến.
#
# - Quy tắc chung là chuyển đổi chúng thành các đối tượng numpy.array trước khi vẽ biểu đồ.

# %%
# chuyển đổi pandas.DataFrame 
a = pd.DataFrame(np.random.rand(4, 5), columns = list('abcde'))
a_asarray = a.values
a_asarray
# Out:
# array([[0.00398065, 0.39122578, 0.44451791, 0.10368224, 0.2004666 ],
#        [0.27439696, 0.61662184, 0.20588475, 0.01461478, 0.17483028],
#        [0.14289321, 0.69852556, 0.99944865, 0.78884313, 0.29125313],
#        [0.80867367, 0.53249478, 0.72727331, 0.06872859, 0.5975687 ]])

# %%
# chuyển đổi numpy.matrix
b = np.matrix([[1, 2], [3, 4]])
b_asarray = np.asarray(b)
b_asarray
# Out:
# array([[1, 2],
#        [3, 4]])

# %% [markdown]
# # Matplotlib coding styles

# %% [markdown]
# 1. Object-oriented (OO) style: explicitly create Figures and Axes, and call methods on them

# %%
x = np.linspace(0, 2, 100) # Sample data.
# Note that even in the OO-style, we use `.pyplot.figure` to create the Figure.
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.plot(x, x, label='linear') # Plot some data on the axes. 
ax.plot(x, x**2, label='quadratic') # Plot more data on the axes... 
ax.plot(x, x**3, label='cubic') # ... and some more.
ax.set_xlabel('x label') # Add an x-label to the axes. 
ax.set_ylabel('y label') # Add a y-label to the axes. 
ax.set_title("Simple Plot") # Add a title to the axes. 
ax.legend(); # Add a legend.

# %% [markdown]
# 2. pyplot style: rely on pyplot to automatically create and manage the Figures and Axes, and use pyplot functions for plotting

# %%
x = np.linspace(0, 2, 100) # Sample data.
plt.figure(figsize=(5, 2.7))
plt.plot(x, x, label='linear') # Plot some data on the (implicit) axes. 
plt.plot(x, x**2, label='quadratic') # etc.
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend();

# %% [markdown]
# In general, we suggest using the OO style, particularly for complicated plots, and functions and scripts that are intended to be reused as part of a larger project.
#
# However, the pyplot style can be very convenient for quick interactive work.

# %%
import matplotlib.cm as cm
np.random.seed(0)
delta = 0.06
x = y = np.arange(-3.0, 3.0, delta)
X, Y = np.meshgrid(x, y)

fig, axs = plt.subplots(3,2,figsize=(5, 8))

axs[0,0].set_title('2D-variable X')
axs[0,0].imshow(X, interpolation='bilinear', origin='lower', extent=[-3, 3, -3, 3])
axs[0,1].set_title('2D-variable Y')
axs[0,1].imshow(Y, interpolation='bilinear', origin='lower', extent=[-3, 3, -3, 3])

# generate 2 bivariate normal distributions
Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X - 1)**2 - (Y - 1)**2)
axs[1,0].set_title('2D normal distribution Z1')
axs[1,0].imshow(Z1, interpolation='bilinear', origin='lower', extent=[-3, 3, -3, 3])
axs[1,1].set_title('2D normal distribution Z2')
axs[1,1].imshow(Z2, interpolation='bilinear', origin='lower', extent=[-3, 3, -3, 3])

axs[2,0].set_title('Z1 + Z2')
axs[2,0].imshow(Z1 + Z2, interpolation='bilinear', origin='lower', extent=[-3, 3, -3, 3])
axs[2,1].set_title('Z1 - Z2')
im=axs[2,1].imshow(Z1 - Z2, interpolation='bilinear', origin='lower', extent=[-3, 3, -3, 3])
plt.colorbar(im)

plt.tight_layout()
plt.show()
